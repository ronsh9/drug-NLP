# %%
import json
import pandas as pd

def analyze_json_file(filepath):
    with open(filepath, 'r') as file:
        data = json.load(file)

    if not isinstance(data, dict):
        print("The top level of the JSON file is not a dictionary.")
        return

    level_1_keys_count = len(data)
    print("Number of keys in level 1 dictionary:", level_1_keys_count)

    # Initialize counters and the list for keys meeting all criteria
    counts = {
        "active_ingredients": 0,
        "disease_information": 0,
        "additional_information": 0,
        "all_criteria": 0
    }
    all_criteria_keys = []

    for key, value in data.items():
        if not isinstance(value, dict):
            continue

        ai_valid = "Active Ingredients" in value and \
                   any(isinstance(v, str) and v for v in value["Active Ingredients"].values() if not pd.isna(v))
        
        di_valid = "Disease Information" in value and \
                   isinstance(value["Disease Information"], dict) and \
                   len(value["Disease Information"]) > 0

        ai_info_valid = "Additional Information" in value and \
                        isinstance(value["Additional Information"], dict) and \
                        len(value["Additional Information"]) > 0

        # Update counters
        counts["active_ingredients"] += ai_valid
        counts["disease_information"] += di_valid
        counts["additional_information"] += ai_info_valid

        # Check if all criteria are met
        if ai_valid and di_valid and ai_info_valid:
            counts["all_criteria"] += 1
            all_criteria_keys.append(key)

    # Print results
    print("Number of keys with valid 'Active Ingredients':", counts["active_ingredients"])
    print("Number of keys with valid 'Disease Information':", counts["disease_information"])
    print("Number of keys with valid 'Additional Information':", counts["additional_information"])
    print("Number of keys satisfying all three criteria:", counts["all_criteria"])

    return all_criteria_keys

# %%
good_keys = analyze_json_file('scraper/data/drug_info.json')
print('---')
good_keys
# Out:
# Number of keys in level 1 dictionary: 7878
# Number of keys with valid 'Active Ingredients': 7283
# Number of keys with valid 'Disease Information': 4212
# Number of keys with valid 'Additional Information': 4283
# Number of keys satisfying all three criteria: 3763
# ---
# ['A-HYDROCORT',
#  'A-METHAPRED',
#  'ABACAVIR SULFATE',
#  'ABACAVIR SULFATE; LAMIVUDINE',
#  'ABACAVIR; DOLUTEGRAVIR; LAMIVUDINE',
#  'ABACAVIR; LAMIVUDINE',
#  'ABILIFY',
#  'ABILIFY ASIMTUFII',
#  'ABIRATERONE ACETATE',
#  'ABITREXATE',
#  'ABLAVAR',
#  'ABRAXANE',
#  'ABREVA',
#  'ABSORICA',
#  'ABSORICA LD',
#  'ABSTRAL',
#  'ACALABRUTINIB',
#  'ACAMPROSATE CALCIUM',
#  'ACARBOSE',
#  'ACCOLATE',
#  'ACCRUFER',
#  'ACCUNEB',
#  'ACCUPRIL',
#  'ACCUTANE',
#  'ACEBUTOLOL HYDROCHLORIDE',
#  'ACEON',
#  'ACEPHEN',
#  'ACETADOTE',
#  'ACETAMINOPHEN',
#  'ACETAMINOPHEN; OXYCODONE HYDROCHLORIDE',
#  'ACETASOL',
#  'ACETAZOLAMIDE',
#  'ACETAZOLAMIDE SODIUM',
#  'ACETIC ACID',
#  'ACETYLCYSTEINE',
#  'ACHROMYCIN',
#  'ACHROMYCIN V',
#  'ACIPHEX',
#  'ACIPHEX SPRINKLE',
#  'ACITRETIN',
#  'ACLOVATE',
#  'ACTH',
#  'ACTHAR',
#  'ACTHAR GEL',
#  'ACTHREL',
#  'ACTICLATE',
#  'ACTICLATE CAP',
#  'ACTICORT',
#  'ACTIGALL',
#  'ACTIQ',
#  'ACTISITE',
#  'ACTONEL',
#  'ACTOS',
#  'ACULAR',
#  'ACULAR LS',
#  'ACUVAIL',
#  'ACYCLOVIR',
#  'ACYCLOVIR SODIUM',
#  'ACZONE',
#  'ADALAT',
#  'ADALAT CC',
#  'ADAPALENE',
#  'ADASUVE',
#  'ADCIRCA',
#  'ADDYI',
#  'ADEFOVIR DIPIVOXIL',
#  'ADEMPAS',
#  'ADENOCARD',
#  'ADENOSCAN',
#  'ADENOSINE',
#  'ADHANSIA XR',
#  'ADIPEX-P',
#  'ADLARITY',
#  'ADLYXIN',
#  'ADMELOG',
#  'ADMELOG SOLOSTAR',
#  'ADRENACLICK',
#  'ADRENALIN',
#  'ADREVIEW',
#  'ADRIAMYCIN PFS',
#  'ADRUCIL',
#  'ADVIL',
#  'ADVIL LIQUI-GELS',
#  'ADZENYS ER',
#  'ADZENYS XR-ODT',
#  'AEMCOLO',
#  'AEROBID',
#  'AFATINIB',
#  'AFEDITAB CR',
#  'AFINITOR',
#  'AFINITOR DISPERZ',
#  'AFRINOL',
#  'AGAMREE',
#  'AGGRASTAT',
#  'AGRYLIN',
#  'AK-PENTOLATE',
#  'AKBETA',
#  'AKLIEF',
#  'AKNE-MYCIN',
#  'AKOVAZ',
#  'AKPRO',
#  'AKTEN',
#  'AKTOB',
#  'ALA-SCALP',
#  'ALAVERT',
#  'ALAWAY',
#  'ALBALON',
#  'ALBENDAZOLE',
#  'ALBENZA',
#  'ALBUTEROL',
#  'ALBUTEROL SULFATE',
#  'ALBUTEROL SULFATE; IPRATROPIUM BROMIDE',
#  'ALCAFTADINE',
#  'ALCAINE',
#  'ALCLOMETASONE DIPROPIONATE',
#  'ALDACTONE',
#  'ALDARA',
#  'ALDOMET',
#  'ALECENSA',
#  'ALENDRONATE SODIUM',
#  'ALEVE',
#  'ALFENTA',
#  'ALFENTANIL',
#  'ALFUZOSIN HYDROCHLORIDE',
#  'ALIMTA',
#  'ALINIA',
#  'ALIQOPA',
#  'ALISKIREN HEMIFUMARATE',
#  'ALKERAN',
#  'ALKERGOT',
#  'ALKINDI SPRINKLE',
#  'ALLEGRA',
#  'ALLEGRA ALLERGY',
#  'ALLEGRA HIVES',
#  'ALLERNAZE',
#  'ALLI',
#  'ALLOPURINOL',
#  'ALLOPURINOL SODIUM',
#  'ALMOTRIPTAN MALATE',
#  'ALOCRIL',
#  'ALOGLIPTIN',
#  'ALOGLIPTIN; METFORMIN HYDROCHLORIDE',
#  'ALOPRIM',
#  'ALORA',
#  'ALOSETRON HYDROCHLORIDE',
#  'ALOXI',
#  'ALPHACAINE',
#  'ALPHAGAN',
#  'ALPHAGAN P',
#  'ALPHALIN',
#  'ALPRAZOLAM',
#  'ALPROSTADIL',
#  'ALSUMA',
#  'ALTABAX',
#  'ALTACE',
#  'ALTOPREV',
#  'ALTRENO',
#  'ALUNBRIG',
#  'ALUPENT',
#  'ALVESCO',
#  'ALVIMOPAN',
#  'ALYQ',
#  'AMANTADINE',
#  'AMANTADINE HYDROCHLORIDE',
#  'AMBIEN',
#  'AMBIEN CR',
#  'AMBISOME',
#  'AMBRISENTAN',
#  'AMCINONIDE',
#  'AMELUZ',
#  'AMERGE',
#  'AMICAR',
#  'AMIDATE',
#  'AMIFOSTINE',
#  'AMIKACIN SULFATE',
#  'AMIKIN',
#  'AMILORIDE HYDROCHLORIDE',
#  'AMINOCAPROIC ACID',
#  'AMINOPHYLLIN',
#  'AMINOPHYLLINE',
#  'AMIODARONE HYDROCHLORIDE',
#  'AMITIZA',
#  'AMITRIPTYLINE HYDROCHLORIDE',
#  'AMLODIPINE BENZOATE',
#  'AMLODIPINE BESYLATE',
#  'AMLODIPINE BESYLATE; BENAZEPRIL HYDROCHLORIDE',
#  'AMLODIPINE MALEATE; BENAZEPRIL HYDROCHLORIDE',
#  'AMMONIA N 13',
#  'AMNESTEEM',
#  'AMNESTROGEN',
#  'AMONDYS 45',
#  'AMOXAPINE',
#  'AMOXICILLIN',
#  'AMOXICILLIN; CLAVULANATE POTASSIUM',
#  'AMOXICILLIN;CLAVULANATE POTASSIUM',
#  'AMOXIL',
#  'AMPHADASE',
#  'AMPHETAMINE',
#  'AMPHETAMINE SULFATE',
#  'AMPHOTEC',
#  'AMPHOTERICIN B',
#  'AMPICILLIN SODIUM',
#  'AMPYRA',
#  'AMRIX',
#  'AMVAZ',
#  'AMYVID',
#  'AMZEEQ',
#  'ANADROL-50',
#  'ANAFRANIL',
#  'ANAGRELIDE HYDROCHLORIDE',
#  'ANAPROX',
#  'ANAPROX DS',
#  'ANASTROZOLE',
#  'ANCEF',
#  'ANCOBON',
#  'ANDRODERM',
#  'ANDROGEL',
#  'ANECTINE',
#  'ANESTACON',
#  'ANGIOMAX',
#  'ANGIOMAX RTU',
#  'ANJESO',
#  'ANSAID',
#  'ANSPOR',
#  'ANTABUSE',
#  'ANTEPAR',
#  'ANTIVERT',
#  'ANTIZOL',
#  'ANTURANE',
#  'ANZEMET',
#  'APHEXDA',
#  'APIXABAN',
#  'APLENZIN',
#  'APOKYN',
#  'APOMORPHINE HYDROCHLORIDE',
#  'APONVIE',
#  'APRACLONIDINE HYDROCHLORIDE',
#  'APREMILAST',
#  'APREPITANT',
#  'APRESOLINE',
#  'APRETUDE',
#  'APRISO',
#  'APTENSIO XR',
#  'APTIOM',
#  'APTIVUS',
#  'AQUAMEPHYTON',
#  'AQUASOL A',
#  'AQUATENSEN',
#  'ARAKODA',
#  'ARALEN',
#  'ARAVA',
#  'ARAZLO',
#  'ARCAPTA NEOHALER',
#  'AREDIA',
#  'ARESTIN',
#  'ARFORMOTEROL TARTRATE',
#  'ARGATROBAN',
#  'ARICEPT',
#  'ARICEPT ODT',
#  'ARIDOL',
#  'ARIMIDEX',
#  'ARIPIPRAZOLE',
#  'ARISTADA',
#  'ARISTOCORT',
#  'ARISTOSPAN',
#  'ARIXTRA',
#  'ARMODAFINIL',
#  'ARMONAIR DIGIHALER',
#  'ARMONAIR RESPICLICK',
#  'ARNUITY ELLIPTA',
#  'AROMASIN',
#  'ARRANON',
#  'ARSENIC TRIOXIDE',
#  'ARTANE',
#  'ARTESUNATE',
#  'ARYMO ER',
#  'ASACOL',
#  'ASACOL HD',
#  'ASCOR',
#  'ASENAPINE MALEATE',
#  'ASENDIN',
#  'ASMANEX HFA',
#  'ASMANEX TWISTHALER',
#  'ASPIRIN; OMEPRAZOLE',
#  'ASPRUZYO SPRINKLE',
#  'ASTAGRAF XL',
#  'ASTELIN',
#  'ASTEPRO',
#  'ASTEPRO ALLERGY',
#  'ASTRAMORPH PF',
#  'ATACAND',
#  'ATARAX',
#  'ATAZANAVIR SULFATE',
#  'ATAZANAVIR SULFATE; RITONAVIR',
#  'ATAZANAVIR SULFATE;RITONAVIR;LAMIVUDINE;ZIDOVUDINE',
#  'ATELVIA',
#  'ATENOLOL',
#  'ATHENTIA NEXT',
#  'ATIVAN',
#  'ATOMOXETINE HYDROCHLORIDE',
#  'ATORVALIQ',
#  'ATORVASTATIN CALCIUM',
#  'ATOVAQUONE',
#  'ATRACURIUM BESYLATE',
#  'ATRALIN',
#  'ATRIDOX',
#  'ATROPINE',
#  'ATROPINE SULFATE',
#  'ATROVENT',
#  'ATROVENT HFA',
#  'AUBAGIO',
#  'AURYXIA',
#  'AUSTEDO',
#  'AUSTEDO XR',
#  'AUVI-Q',
#  'AVAGE',
#  'AVANDIA',
#  'AVAPRO',
#  'AVC',
#  'AVEED',
#  'AVELOX',
#  'AVENTYL',
#  'AVINZA',
#  'AVITA',
#  'AVODART',
#  'AXERT',
#  'AXID',
#  'AXID AR',
#  'AXIRON',
#  'AXITINIB',
#  'AXUMIN',
#  'AYGESTIN',
#  'AYVAKIT',
#  'AZACITIDINE',
#  'AZACTAM',
#  'AZASAN',
#  'AZASITE',
#  'AZATHIOPRINE',
#  'AZATHIOPRINE SODIUM',
#  'AZEDRA',
#  'AZELAIC ACID',
#  'AZELASTINE HYDROCHLORIDE',
#  'AZELEX',
#  'AZILECT',
#  'AZILSARTAN MEDOXOMIL',
#  'AZITHROMYCIN',
#  'AZMACORT',
#  'AZOLID',
#  'AZOPT',
#  'AZTREONAM',
#  'AZULFIDINE',
#  'AZULFIDINE EN-TABS',
#  'BACLOFEN',
#  'BACTOCILL',
#  'BACTROBAN',
#  'BAL',
#  'BALSALAZIDE DISODIUM',
#  'BALVERSA',
#  'BANAN',
#  'BANZEL',
#  'BAQSIMI',
#  'BARACLUDE',
#  'BARHEMSYS',
#  'BAXDELA',
#  'BECLOVENT',
#  'BECONASE',
#  'BECONASE AQ',
#  'BEEPEN-VK',
#  'BELBUCA',
#  'BELEODAQ',
#  'BELIX',
#  'BELRAPZO',
#  'BENAZEPRIL HYDROCHLORIDE',
#  'BENDAMUSTINE HYDROCHLORIDE',
#  'BENDEKA',
#  'BENEMID',
#  'BENICAR',
#  'BENOQUIN',
#  'BENOXINATE HYDROCHLORIDE',
#  'BENTYL',
#  'BENZEDRINE',
#  'BENZONATATE',
#  'BENZOYL PEROXIDE; CLINDAMYCIN PHOSPHATE',
#  'BENZPHETAMINE HYDROCHLORIDE',
#  'BENZTROPINE MESYLATE',
#  'BEPOTASTINE BESILATE',
#  'BEPREVE',
#  'BERUBIGEN',
#  'BESIVANCE',
#  'BETA-HC',
#  'BETAGAN',
#  'BETAINE',
#  'BETALIN S',
#  'BETAMETHASONE DIPROPIONATE',
#  'BETAMETHASONE SODIUM PHOSPHATE',
#  'BETAMETHASONE VALERATE',
#  'BETAPACE',
#  'BETAPACE AF',
#  'BETAPEN-VK',
#  'BETAXOLOL HYDROCHLORIDE',
#  'BETAXON',
#  'BETHANECHOL CHLORIDE',
#  'BETHKIS',
#  'BETIMOL',
#  'BETOPTIC',
#  'BETOPTIC S',
#  'BEVYXXA',
#  'BEXAROTENE',
#  'BEXTRA',
#  'BIAXIN',
#  'BIAXIN XL',
#  'BICALUTAMIDE',
#  'BICILLIN L-A',
#  'BICNU',
#  'BILTRICIDE',
#  'BIMATOPROST',
#  'BINOSTO',
#  'BISOPROLOL FUMARATE',
#  'BIVALIRUDIN',
#  'BIVALIRUDIN IN 0.9% SODIUM CHLORIDE',
#  'BLENOXANE',
#  'BLEOMYCIN SULFATE',
#  'BLEPH-10',
#  'BLOCADREN',
#  'BLOXIVERZ',
#  'BONIVA',
#  'BONTRIL',
#  'BONTRIL PDM',
#  'BOROFAIR',
#  'BORTEZOMIB',
#  'BOSENTAN',
#  'BOSULIF',
#  'BRAFTOVI',
#  'BRENZAVVY',
#  'BRETHAIRE',
#  'BRETHINE',
#  'BRETYLIUM TOSYLATE',
#  'BRETYLOL',
#  'BREVIBLOC',
#  'BREVITAL SODIUM',
#  'BREXAFEMME',
#  'BREXPIPRAZOLE',
#  'BRICANYL',
#  'BRILINTA',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE; TIMOLOL MALEATE',
#  'BRINZOLAMIDE',
#  'BRISDELLE',
#  'BRISTAGEN',
#  'BRIVARACETAM',
#  'BRIVIACT',
#  'BRIXADI',
#  'BROMDAY',
#  'BROMFENAC SODIUM',
#  'BROMOCRIPTINE MESYLATE',
#  'BROMPHENIRAMINE MALEATE',
#  'BRONCHITOL',
#  'BROVANA',
#  'BRUKINSA',
#  'BRYHALI',
#  'BUCLADIN-S',
#  'BUDESONIDE',
#  'BUMETANIDE',
#  'BUMEX',
#  'BUPHENYL',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'BUPRENEX',
#  'BUPRENORPHINE',
#  'BUPRENORPHINE HYDROCHLORIDE',
#  'BUPRENORPHINE HYDROCHLORIDE; NALOXONE HYDROCHLORIDE',
#  'BUPROPION HYDROBROMIDE',
#  'BUPROPION HYDROCHLORIDE',
#  'BUSPAR',
#  'BUSPIRONE HYDROCHLORIDE',
#  'BUSULFAN',
#  'BUSULFEX',
#  'BUTABARBITAL',
#  'BUTABARBITAL SODIUM',
#  'BUTALAN',
#  'BUTALBITAL; ACETAMINOPHEN; CAFFEINE; CODEINE',
#  'BUTENAFINE HYDROCHLORIDE',
#  'BUTISOL SODIUM',
#  'BUTOCONAZOLE NITRATE',
#  'BUTORPHANOL TARTRATE',
#  'BUTRANS',
#  'BYDUREON BCISE',
#  'BYETTA',
#  'BYFAVO',
#  'BYLVAY',
#  'BYSTOLIC',
#  'CABAZITAXEL',
#  'CABERGOLINE',
#  'CABOMETYX',
#  'CABOZANTINIB',
#  'CAFCIT',
#  'CAFFEINE CITRATE',
#  'CALAN',
#  'CALAN SR',
#  'CALCIJEX',
#  'CALCIMAR',
#  'CALCIPOTRIENE',
#  'CALCITONIN-SALMON',
#  'CALCITRIOL',
#  'CALCIUM ACETATE',
#  'CALCIUM DISODIUM VERSENATE',
#  'CALDEROL',
#  'CALDOLOR',
#  'CALOMIST',
#  'CALQUENCE',
#  'CAMBIA',
#  'CAMILA',
#  'CAMPRAL',
#  'CAMPTOSAR',
#  'CAMZYOS',
#  'CANAGLIFLOZIN',
#  'CANAGLIFLOZIN; METFORMIN HYDROCHLORIDE',
#  'CANASA',
#  'CANCIDAS',
#  'CANDESARTAN CILEXETIL',
#  'CANDESARTAN CILEXETIL; HYDROCHLOROTHIAZIDE',
#  'CANDEX',
#  'CANTIL',
#  'CAP-PROFEN',
#  'CAPECITABINE',
#  'CAPEX',
#  'CAPLYTA',
#  'CAPOTEN',
#  'CAPRELSA',
#  'CAPTOPRIL',
#  'CARAC',
#  'CARAFATE',
#  'CARBACHOL',
#  'CARBAGLU',
#  'CARBAMAZEPINE',
#  'CARBASTAT',
#  'CARBATROL',
#  'CARBIDOPA',
#  'CARBIDOPA; LEVODOPA',
#  'CARBINOXAMINE MALEATE',
#  'CARBOCAINE',
#  'CARBOPLATIN',
#  'CARBOPROST TROMETHAMINE',
#  'CARDENE',
#  'CARDENE SR',
#  'CARDIOGEN-82',
#  'CARDIZEM',
#  'CARDIZEM CD',
#  'CARDIZEM LA',
#  'CARDURA',
#  'CARDURA XL',
#  'CARFILZOMIB',
#  'CARGLUMIC ACID',
#  'CARIPRAZINE HYDROCHLORIDE',
#  'CARISOPRODOL',
#  'CARMOL HC',
#  'CARMUSTINE',
#  'CARNEXIV',
#  'CARNITOR',
#  'CARNITOR SF',
#  'CAROSPIR',
#  'CARTEOLOL HYDROCHLORIDE',
#  'CARTIA XT',
#  'CARVEDILOL',
#  'CARVEDILOL PHOSPHATE',
#  'CASODEX',
#  'CASPOFUNGIN ACETATE',
#  'CATAFLAM',
#  'CATAPRES',
#  'CATAPRES-TTS-1',
#  'CATAPRES-TTS-2',
#  'CATAPRES-TTS-3',
#  'CAVERJECT IMPULSE',
#  'CAYSTON',
#  'CECLOR',
#  'CECLOR CD',
#  'CEDAX',
#  'CEFACLOR',
#  'CEFADYL',
#  'CEFAZOLIN SODIUM',
#  'CEFDINIR',
#  'CEFEPIME HYDROCHLORIDE',
#  'CEFIXIME',
#  'CEFIZOX',
#  'CEFOBID',
#  'CEFOTAN',
#  'CEFOTAXIME',
#  'CEFOTAXIME SODIUM',
#  'CEFOTETAN',
#  'CEFOXITIN',
#  'CEFPODOXIME PROXETIL',
#  'CEFPROZIL',
#  'CEFTAZIDIME',
#  'CEFTIN',
#  'CEFTRIAXONE',
#  'CEFTRIAXONE SODIUM',
#  'CEFUROXIME',
#  'CEFUROXIME AXETIL',
#  'CEFUROXIME SODIUM',
#  'CEFZIL',
#  'CELEBREX',
#  'CELECOXIB',
#  'CELESTONE',
#  'CELESTONE SOLUSPAN',
#  'CELEXA',
#  'CELLCEPT',
#  'CELONTIN',
#  'CENESTIN',
#  'CENTANY',
#  'CENTRAX',
#  'CEPHALEXIN',
#  'CEPHALOTHIN',
#  'CEPHALOTHIN SODIUM',
#  'CEPHAPIRIN SODIUM',
#  'CEPHRADINE',
#  'CEPHULAC',
#  'CEPTAZ',
#  'CEQUA',
#  'CERADON',
#  'CERDELGA',
#  'CEREBYX',
#  'CERIANNA',
#  'CERUBIDINE',
#  'CESAMET',
#  'CETACORT',
#  'CETAMIDE',
#  'CETIRIZINE HYDROCHLORIDE',
#  'CETIRIZINE HYDROCHLORIDE HIVES',
#  'CETIRIZINE HYDROCHLORIDE HIVES RELIEF',
#  'CETRAXAL',
#  'CETRORELIX ACETATE',
#  'CETROTIDE',
#  'CETYLEV',
#  'CEVIMELINE HYDROCHLORIDE',
#  'CHANTIX',
#  'CHEMET',
#  'CHENIX',
#  'CHENODIOL',
#  'CHIBROXIN',
#  "CHILDREN'S ADVIL",
#  "CHILDREN'S ELIXSURE",
#  "CHILDREN'S IBUPROFEN",
#  "CHILDREN'S MOTRIN",
#  'CHIRHOSTIM',
#  'CHIROCAINE',
#  'CHLOR-TRIMETON',
#  'CHLORAMPHENICOL',
#  'CHLORAMPHENICOL SODIUM SUCCINATE',
#  'CHLORDIAZEPOXIDE HYDROCHLORIDE',
#  'CHLORDIAZEPOXIDE HYDROCHLORIDE;CLIDINIUM BROMIDE',
#  'CHLORHEXIDINE GLUCONATE',
#  'CHLOROMYCETIN',
#  'CHLOROPROCAINE HYDROCHLORIDE',
#  'CHLOROQUINE PHOSPHATE',
#  'CHLOROTHIAZIDE',
#  'CHLOROTHIAZIDE SODIUM',
#  'CHLORPHENIRAMINE MALEATE',
#  'CHLORPROMAZINE HYDROCHLORIDE',
#  'CHLORPROPAMIDE',
#  'CHLORTHALIDONE',
#  'CHLORZOXAZONE',
#  'CHOLAC',
#  'CHOLBAM',
#  'CHOLEDYL',
#  'CHOLESTYRAMINE',
#  'CHOLESTYRAMINE LIGHT',
#  'CHOLYBAR',
#  'CHROMIC CHLORIDE',
#  'CHRONULAC',
#  'CIALIS',
#  'CIBINQO',
#  'CICLOPIROX',
#  'CIDA-STAT',
#  'CIDOFOVIR',
#  'CILOSTAZOL',
#  'CILOXAN',
#  'CIMETIDINE',
#  'CIMETIDINE HYDROCHLORIDE',
#  'CIN-QUIN',
#  'CINACALCET HYDROCHLORIDE',
#  'CINVANTI',
#  'CIPRO XR',
#  'CIPROFLOXACIN',
#  'CIPROFLOXACIN HYDROCHLORIDE',
#  'CIRCANOL',
#  'CISATRACURIUM BESYLATE',
#  'CISPLATIN',
#  'CITALOPRAM HYDROBROMIDE',
#  'CITANEST',
#  'CITANEST PLAIN',
#  'CITRIC ACID; MAGNESIUM OXIDE; SODIUM PICOSULFATE',
#  'CLADRIBINE',
#  'CLAFORAN',
#  'CLARAVIS',
#  'CLARINEX',
#  'CLARITHROMYCIN',
#  'CLARITIN',
#  'CLARITIN REDITABS',
#  'CLEMASTINE FUMARATE',
#  'CLEOCIN',
#  'CLEOCIN HYDROCHLORIDE',
#  'CLEOCIN PHOSPHATE',
#  'CLEOCIN T',
#  'CLEVIPREX',
#  'CLIMARA',
#  'CLINDA-DERM',
#  'CLINDAGEL',
#  'CLINDAMYCIN HYDROCHLORIDE',
#  'CLINDAMYCIN PALMITATE HYDROCHLORIDE',
#  'CLINDAMYCIN PHOSPHATE',
#  'CLINDAMYCIN PHOSPHATE; TRETINOIN',
#  'CLINDESSE',
#  'CLINDETS',
#  'CLINORIL',
#  'CLISTIN',
#  'CLOBAZAM',
#  'CLOBETASOL PROPIONATE',
#  'CLOBETASOL PROPIONATE (EMOLLIENT)',
#  'CLOBEX',
#  'CLOCORTOLONE PIVALATE',
#  'CLOFARABINE',
#  'CLOLAR',
#  'CLOMID',
#  'CLOMIPHENE CITRATE',
#  'CLOMIPRAMINE HYDROCHLORIDE',
#  'CLONAZEPAM',
#  'CLONIDINE',
#  'CLONIDINE HYDROCHLORIDE',
#  'CLOPIDOGREL BISULFATE',
#  'CLORAZEPATE DIPOTASSIUM',
#  'CLOROTEKAL',
#  'CLOTRIMAZOLE',
#  'CLOXACILLIN SODIUM',
#  'CLOZAPINE',
#  'CLOZARIL',
#  'CODEINE SULFATE',
#  'COGENTIN',
#  'COLAZAL',
#  'COLCHICINE',
#  'COLCRYS',
#  'COLESEVELAM HYDROCHLORIDE',
#  'COLESTID',
#  'COLESTIPOL HYDROCHLORIDE',
#  'COLOCORT',
#  'COMETRIQ',
#  'COMPAZINE',
#  'COMPRO',
#  'COMTAN',
#  'CONCERTA',
#  'CONDYLOX',
#  'CONJUPRI',
#  'CONSTILAC',
#  'CONSTULOSE',
#  'CONZIP',
#  'COPAXONE',
#  'COPEGUS',
#  'COPIKTRA',
#  'CORDARONE',
#  'CORDRAN',
#  'CORDRAN SP',
#  'COREG',
#  'COREG CR',
#  'CORGARD',
#  'CORLANOR',
#  'CORLOPAM',
#  'CORMAX',
#  'CORPHEDRA',
#  'CORTAN',
#  'CORTENEMA',
#  'CORTICOTROPIN',
#  'CORTIFOAM',
#  'CORTISONE ACETATE',
#  'CORTROSYN',
#  'CORVERT',
#  'COSELA',
#  'COSMEGEN',
#  'COSYNTROPIN',
#  'COTELLIC',
#  'COTEMPLA XR-ODT',
#  'COUMADIN',
#  'COVERA-HS',
#  'COXANTO',
#  'COZAAR',
#  'CRESTOR',
#  'CRINONE',
#  'CRIXIVAN',
#  'CROLOM',
#  'CROMOLYN SODIUM',
#  'CROMOPTIC',
#  'CRYSTODIGIN',
#  'CUBICIN',
#  'CUBICIN RF',
#  'CUPRIC CHLORIDE',
#  'CUPRIC SULFATE',
#  'CUPRIMINE',
#  'CUTIVATE',
#  'CUVPOSA',
#  'CUVRIOR',
#  'CYANOCOBALAMIN',
#  'CYANOKIT',
#  'CYCLOBENZAPRINE HYDROCHLORIDE',
#  'CYCLOCORT',
#  'CYCLOGYL',
#  'CYCLOPENTOLATE HYDROCHLORIDE',
#  'CYCLOPHOSPHAMIDE',
#  'CYCLOSET',
#  'CYCLOSPORINE',
#  'CYKLOKAPRON',
#  'CYMBALTA',
#  'CYPROHEPTADINE HYDROCHLORIDE',
#  'CYSTADANE',
#  'CYSTADROPS',
#  'CYSTAGON',
#  'CYSTARAN',
#  'CYSTEINE HYDROCHLORIDE',
#  'CYTALUX',
#  'CYTARABINE',
#  'CYTOMEL',
#  'CYTOSAR-U',
#  'CYTOTEC',
#  'CYTOVENE',
#  'CYTOXAN',
#  'D.H.E. 45',
#  'DABIGATRAN ETEXILATE MESYLATE',
#  'DACARBAZINE',
#  'DACOGEN',
#  'DACTINOMYCIN',
#  'DAKLINZA',
#  'DALFAMPRIDINE',
#  'DALIRESP',
#  'DALMANE',
#  'DALVANCE',
#  'DANAZOL',
#  'DANOCRINE',
#  'DANTRIUM',
#  'DANTROLENE SODIUM',
#  'DAPAGLIFLOZIN',
#  'DAPAGLIFLOZIN;METFORMIN HYDROCHLORIDE',
#  'DAPIPRAZOLE HYDROCHLORIDE',
#  'DAPSONE',
#  'DAPTOMYCIN',
#  'DAPZURA RT',
#  'DARANIDE',
#  'DARAPRIM',
#  'DARIFENACIN',
#  'DARIFENACIN HYDROBROMIDE',
#  'DARTISLA ODT',
#  'DARUNAVIR',
#  'DARUNAVIR ETHANOLATE',
#  'DARVON-N',
#  'DASATINIB',
#  'DATSCAN',
#  'DAUNORUBICIN HYDROCHLORIDE',
#  'DAUNOXOME',
#  'DAURISMO',
#  'DAYBUE',
#  'DAYPRO',
#  'DAYPRO ALTA',
#  'DAYTRANA',
#  'DAYVIGO',
#  'DDAVP',
#  'DECA-DURABOLIN',
#  'DECADRON',
#  'DECADRON-LA',
#  'DECITABINE',
#  'DECLOMYCIN',
#  'DEFERASIROX',
#  'DEFERIPRONE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFITELIO',
#  'DEFLAZACORT',
#  'DELALUTIN',
#  'DELATESTRYL',
#  'DELAXIN',
#  'DELESTROGEN',
#  'DELSYM',
#  'DELTALIN',
#  'DELTASONE',
#  'DELZICOL',
#  'DEMADEX',
#  'DEMECLOCYCLINE HYDROCHLORIDE',
#  'DEMEROL',
#  'DEMSER',
#  'DENAVIR',
#  'DENDRID',
#  'DENTIPATCH',
#  'DEOXYCHOLIC ACID',
#  'DEPACON',
#  'DEPAKENE',
#  'DEPAKOTE',
#  'DEPAKOTE ER',
#  'DEPEN',
#  'DEPO-ESTRADIOL',
#  'DEPO-MEDROL',
#  'DEPO-PROVERA',
#  'DEPO-SUBQ PROVERA 104',
#  'DEPO-TESTOSTERONE',
#  'DEPOCYT',
#  'DEPODUR',
#  'DERMA-SMOOTHE/FS',
#  'DERMATOP',
#  'DERMATOP E EMOLLIENT',
#  'DERMOTIC',
#  'DESFERAL',
#  'DESFLURANE',
#  'DESIPRAMINE HYDROCHLORIDE',
#  'DESLORATADINE',
#  'DESMOPRESSIN ACETATE',
#  'DESOGESTREL; ETHINYL',
#  'DESOGESTREL; ETHINYL ESTRADIOL',
#  'DESONATE',
#  'DESONIDE',
#  'DESOWEN',
#  'DESOXIMETASONE',
#  'DESOXYN',
#  'DESVENLAFAXINE',
#  'DESVENLAFAXINE SUCCINATE',
#  'DESYREL',
#  'DETECTNET',
#  'DETROL',
#  'DETROL LA',
#  'DEXAMETHASONE',
#  'DEXAMETHASONE ACETATE',
#  'DEXAMETHASONE INTENSOL',
#  'DEXAMETHASONE SODIUM PHOSPHATE',
#  'DEXCHLORPHENIRAMINE MALEATE',
#  'DEXEDRINE',
#  'DEXFERRUM',
#  'DEXILANT',
#  'DEXILANT SOLUTAB',
#  'DEXLANSOPRAZOLE',
#  'DEXMEDETOMIDINE HYDROCHLORIDE',
#  'DEXMETHYLPHENIDATE HYDROCHLORIDE',
#  'DEXRAZOXANE HYDROCHLORIDE',
#  'DEXTENZA',
#  'DEXTROAMPHETAMINE SACCHARATE; AMPHETAMINE ASPARTATE MONOHYDRATE; DEXTROAMPHETAMINE SULFATE; AMPHETAMINE SULFATE',
#  'DEXTROAMPHETAMINE SULFATE',
#  'DEXTROMETHORPHAN POLISTIREX',
#  'DEXTROSTAT',
#  'DIABETA',
#  'DIABINESE',
#  'DIACOMIT',
#  'DIAL',
#  'DIAMOX',
#  'DIASTAT',
#  'DIAZEPAM',
#  'DIAZEPAM INTENSOL',
#  'DIAZOXIDE',
#  'DIBENZYLINE',
#  'DICHLORPHENAMIDE',
#  'DICLOFENAC',
#  'DICLOFENAC POTASSIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOXACILLIN SODIUM',
#  'DICYCLOMINE HYDROCHLORIDE',
#  'DIDANOSINE',
#  'DIDREX',
#  'DIDRONEL',
#  'DIETHYLPROPION HYDROCHLORIDE',
#  'DIFFERIN',
#  'DIFICID',
#  'DIFLORASONE DIACETATE',
#  'DIFLUCAN',
#  'DIFLUNISAL',
#  'DIFLUPREDNATE',
#  'DIGOXIN',
#  'DIHYDROERGOTAMINE MESYLATE',
#  'DILACOR XR',
#  'DILANTIN',
#  'DILANTIN-125',
#  'DILATRATE-SR',
#  'DILAUDID',
#  'DILAUDID-HP',
#  'DILOR',
#  'DILT-CD',
#  'DILTIAZEM HYDROCHLORIDE',
#  'DILTZAC',
#  'DIMENHYDRINATE',
#  'DIMETANE',
#  'DIMETHYL FUMARATE',
#  'DIMETHYL SULFOXIDE',
#  'DIOVAN',
#  'DIPENTUM',
#  'DIPHENHYDRAMINE HYDROCHLORIDE',
#  'DIPIVEFRIN HYDROCHLORIDE',
#  'DIPRIVAN',
#  'DIPROLENE',
#  'DIPROLENE AF',
#  'DIPROSONE',
#  'DIPYRIDAMOLE',
#  'DISIPAL',
#  'DISOPHROL',
#  'DISOPYRAMIDE PHOSPHATE',
#  'DISPERMOX',
#  'DISULFIRAM',
#  'DITROPAN',
#  'DITROPAN XL',
#  'DIULO',
#  'DIURIL',
#  'DIVALPROEX SODIUM',
#  'DIVIGEL',
#  ...]

# %%
print(good_keys[:1500])
# Out:
# ['A-HYDROCORT', 'A-METHAPRED', 'ABACAVIR SULFATE', 'ABACAVIR SULFATE; LAMIVUDINE', 'ABACAVIR; DOLUTEGRAVIR; LAMIVUDINE', 'ABACAVIR; LAMIVUDINE', 'ABILIFY', 'ABILIFY ASIMTUFII', 'ABIRATERONE ACETATE', 'ABITREXATE', 'ABLAVAR', 'ABRAXANE', 'ABREVA', 'ABSORICA', 'ABSORICA LD', 'ABSTRAL', 'ACALABRUTINIB', 'ACAMPROSATE CALCIUM', 'ACARBOSE', 'ACCOLATE', 'ACCRUFER', 'ACCUNEB', 'ACCUPRIL', 'ACCUTANE', 'ACEBUTOLOL HYDROCHLORIDE', 'ACEON', 'ACEPHEN', 'ACETADOTE', 'ACETAMINOPHEN', 'ACETAMINOPHEN; OXYCODONE HYDROCHLORIDE', 'ACETASOL', 'ACETAZOLAMIDE', 'ACETAZOLAMIDE SODIUM', 'ACETIC ACID', 'ACETYLCYSTEINE', 'ACHROMYCIN', 'ACHROMYCIN V', 'ACIPHEX', 'ACIPHEX SPRINKLE', 'ACITRETIN', 'ACLOVATE', 'ACTH', 'ACTHAR', 'ACTHAR GEL', 'ACTHREL', 'ACTICLATE', 'ACTICLATE CAP', 'ACTICORT', 'ACTIGALL', 'ACTIQ', 'ACTISITE', 'ACTONEL', 'ACTOS', 'ACULAR', 'ACULAR LS', 'ACUVAIL', 'ACYCLOVIR', 'ACYCLOVIR SODIUM', 'ACZONE', 'ADALAT', 'ADALAT CC', 'ADAPALENE', 'ADASUVE', 'ADCIRCA', 'ADDYI', 'ADEFOVIR DIPIVOXIL', 'ADEMPAS', 'ADENOCARD', 'ADENOSCAN', 'ADENOSINE', 'ADHANSIA XR', 'ADIPEX-P', 'ADLARITY', 'ADLYXIN', 'ADMELOG', 'ADMELOG SOLOSTAR', 'ADRENACLICK', 'ADRENALIN', 'ADREVIEW', 'ADRIAMYCIN PFS', 'ADRUCIL', 'ADVIL', 'ADVIL LIQUI-GELS', 'ADZENYS ER', 'ADZENYS XR-ODT', 'AEMCOLO', 'AEROBID', 'AFATINIB', 'AFEDITAB CR', 'AFINITOR', 'AFINITOR DISPERZ', 'AFRINOL', 'AGAMREE', 'AGGRASTAT', 'AGRYLIN', 'AK-PENTOLATE', 'AKBETA', 'AKLIEF', 'AKNE-MYCIN', 'AKOVAZ', 'AKPRO', 'AKTEN', 'AKTOB', 'ALA-SCALP', 'ALAVERT', 'ALAWAY', 'ALBALON', 'ALBENDAZOLE', 'ALBENZA', 'ALBUTEROL', 'ALBUTEROL SULFATE', 'ALBUTEROL SULFATE; IPRATROPIUM BROMIDE', 'ALCAFTADINE', 'ALCAINE', 'ALCLOMETASONE DIPROPIONATE', 'ALDACTONE', 'ALDARA', 'ALDOMET', 'ALECENSA', 'ALENDRONATE SODIUM', 'ALEVE', 'ALFENTA', 'ALFENTANIL', 'ALFUZOSIN HYDROCHLORIDE', 'ALIMTA', 'ALINIA', 'ALIQOPA', 'ALISKIREN HEMIFUMARATE', 'ALKERAN', 'ALKERGOT', 'ALKINDI SPRINKLE', 'ALLEGRA', 'ALLEGRA ALLERGY', 'ALLEGRA HIVES', 'ALLERNAZE', 'ALLI', 'ALLOPURINOL', 'ALLOPURINOL SODIUM', 'ALMOTRIPTAN MALATE', 'ALOCRIL', 'ALOGLIPTIN', 'ALOGLIPTIN; METFORMIN HYDROCHLORIDE', 'ALOPRIM', 'ALORA', 'ALOSETRON HYDROCHLORIDE', 'ALOXI', 'ALPHACAINE', 'ALPHAGAN', 'ALPHAGAN P', 'ALPHALIN', 'ALPRAZOLAM', 'ALPROSTADIL', 'ALSUMA', 'ALTABAX', 'ALTACE', 'ALTOPREV', 'ALTRENO', 'ALUNBRIG', 'ALUPENT', 'ALVESCO', 'ALVIMOPAN', 'ALYQ', 'AMANTADINE', 'AMANTADINE HYDROCHLORIDE', 'AMBIEN', 'AMBIEN CR', 'AMBISOME', 'AMBRISENTAN', 'AMCINONIDE', 'AMELUZ', 'AMERGE', 'AMICAR', 'AMIDATE', 'AMIFOSTINE', 'AMIKACIN SULFATE', 'AMIKIN', 'AMILORIDE HYDROCHLORIDE', 'AMINOCAPROIC ACID', 'AMINOPHYLLIN', 'AMINOPHYLLINE', 'AMIODARONE HYDROCHLORIDE', 'AMITIZA', 'AMITRIPTYLINE HYDROCHLORIDE', 'AMLODIPINE BENZOATE', 'AMLODIPINE BESYLATE', 'AMLODIPINE BESYLATE; BENAZEPRIL HYDROCHLORIDE', 'AMLODIPINE MALEATE; BENAZEPRIL HYDROCHLORIDE', 'AMMONIA N 13', 'AMNESTEEM', 'AMNESTROGEN', 'AMONDYS 45', 'AMOXAPINE', 'AMOXICILLIN', 'AMOXICILLIN; CLAVULANATE POTASSIUM', 'AMOXICILLIN;CLAVULANATE POTASSIUM', 'AMOXIL', 'AMPHADASE', 'AMPHETAMINE', 'AMPHETAMINE SULFATE', 'AMPHOTEC', 'AMPHOTERICIN B', 'AMPICILLIN SODIUM', 'AMPYRA', 'AMRIX', 'AMVAZ', 'AMYVID', 'AMZEEQ', 'ANADROL-50', 'ANAFRANIL', 'ANAGRELIDE HYDROCHLORIDE', 'ANAPROX', 'ANAPROX DS', 'ANASTROZOLE', 'ANCEF', 'ANCOBON', 'ANDRODERM', 'ANDROGEL', 'ANECTINE', 'ANESTACON', 'ANGIOMAX', 'ANGIOMAX RTU', 'ANJESO', 'ANSAID', 'ANSPOR', 'ANTABUSE', 'ANTEPAR', 'ANTIVERT', 'ANTIZOL', 'ANTURANE', 'ANZEMET', 'APHEXDA', 'APIXABAN', 'APLENZIN', 'APOKYN', 'APOMORPHINE HYDROCHLORIDE', 'APONVIE', 'APRACLONIDINE HYDROCHLORIDE', 'APREMILAST', 'APREPITANT', 'APRESOLINE', 'APRETUDE', 'APRISO', 'APTENSIO XR', 'APTIOM', 'APTIVUS', 'AQUAMEPHYTON', 'AQUASOL A', 'AQUATENSEN', 'ARAKODA', 'ARALEN', 'ARAVA', 'ARAZLO', 'ARCAPTA NEOHALER', 'AREDIA', 'ARESTIN', 'ARFORMOTEROL TARTRATE', 'ARGATROBAN', 'ARICEPT', 'ARICEPT ODT', 'ARIDOL', 'ARIMIDEX', 'ARIPIPRAZOLE', 'ARISTADA', 'ARISTOCORT', 'ARISTOSPAN', 'ARIXTRA', 'ARMODAFINIL', 'ARMONAIR DIGIHALER', 'ARMONAIR RESPICLICK', 'ARNUITY ELL ...

# %%
print(good_keys[1500:3000])
# Out:
# ['HALAVEN', 'HALCINONIDE', 'HALDOL', 'HALOBETASOL PROPIONATE', 'HALOBETASOL PROPIONATE; TAZAROTENE', 'HALOG', 'HALOG-E', 'HALOPERIDOL', 'HALOPERIDOL DECANOATE', 'HALOPERIDOL LACTATE', 'HALOTESTIN', 'HALOTHANE', 'HEATHER', 'HECTOROL', 'HELICOSOL', 'HEMABATE', 'HEMADY', 'HEMANGEOL', 'HEPARIN LOCK FLUSH', 'HEPARIN SODIUM', 'HEPSERA', 'HER STYLE', 'HERPLEX', 'HETLIOZ', 'HETLIOZ LQ', 'HETRAZAN', 'HEXA-BETALIN', 'HEXA-GERM', 'HEXASCRUB', 'HIBICLENS', 'HISERPIA', 'HISPRIL', 'HISTAMINE PHOSPHATE', 'HMS', 'HORIZANT', 'HUMATIN', 'HUMULIN R KWIKPEN', 'HYCAMTIN', 'HYDASE', 'HYDELTRA-TBA', 'HYDELTRASOL', 'HYDERGINE', 'HYDERGINE LC', 'HYDRALAZINE HYDROCHLORIDE', 'HYDRAMINE', 'HYDREA', 'HYDROCHLOROTHIAZIDE', 'HYDROCHLOROTHIAZIDE; IRBESARTAN', 'HYDROCHLOROTHIAZIDE; VALSARTAN', 'HYDROCODONE', 'HYDROCORTISONE', 'HYDROCORTISONE ACETATE', 'HYDROCORTISONE BUTYRATE', 'HYDROCORTISONE SODIUM PHOSPHATE', 'HYDROCORTISONE SODIUM SUCCINATE', 'HYDROCORTISONE VALERATE', 'HYDRODIURIL', 'HYDROFLUMETHIAZIDE', 'HYDROGENATED ERGOT ALKALOIDS', 'HYDROMORPHONE HYDROCHLORIDE', 'HYDROXOCOBALAMIN', 'HYDROXYCHLOROQUINE SULFATE', 'HYDROXYPROGESTERONE CAPROATE', 'HYDROXYUREA', 'HYDROXYZINE', 'HYDROXYZINE HYDROCHLORIDE', 'HYDROXYZINE PAMOATE', 'HYFTOR', 'HYGROTON', 'HYPERSTAT', 'HYSINGLA ER', 'HYTONE', 'HYTRIN', 'IBANDRONATE SODIUM', 'IBRANCE', 'IBRUTINIB', 'IBSRELA', 'IBU', 'IBUPROFEN', 'IBUPROFEN LYSINE', 'IBUPROFEN SODIUM', 'IBUTILIDE FUMARATE', 'ICATIBANT ACETATE', 'ICLUSIG', 'IDAMYCIN', 'IDAMYCIN PFS', 'IDARUBICIN HYDROCHLORIDE', 'IDHIFA', 'IFEX', 'IFOSFAMIDE', 'IGALMI', 'IHEEZO', 'ILEVRO', 'ILOPERIDONE', 'ILOSONE', 'ILOTYCIN', 'ILUVIEN', 'IMATINIB MESYLATE', 'IMBRUVICA', 'IMCIVREE', 'IMDUR', 'IMIPRAMINE HYDROCHLORIDE', 'IMIPRAMINE PAMOATE', 'IMIQUIMOD', 'IMITREX', 'IMMPHENTIV', 'IMODIUM A-D', 'IMPAVIDO', 'IMPEKLO', 'IMPLANON', 'IMPOYZ', 'IMURAN', 'IMVEXXY', 'INAPSINE', 'INBRIJA', 'INCASSIA', 'INCIVEK', 'INCRUSE ELLIPTA', 'INDAPAMIDE', 'INDERAL', 'INDERAL LA', 'INDOCIN', 'INDOMETHACIN', 'INDOMETHACIN SODIUM', 'INFED', 'INFLAMASE MILD', 'INFUGEM', 'INGENOL MEBUTATE', 'INGREZZA', 'INH', 'INJECTAPAP', 'INLYTA', 'INNOFEM', 'INNOPRAN XL', 'INOMAX', 'INPEFA', 'INREBIC', 'INSPRA', 'INTAL', 'INTEGRILIN', 'INTELENCE', 'INTERMEZZO', 'INTRAROSA', 'INTROPIN', 'INTUNIV', 'INVANZ', 'INVEGA', 'INVEGA HAFYERA', 'INVEGA SUSTENNA', 'INVEGA TRINZA', 'INVELTYS', 'INVERSINE', 'INVIRASE', 'INVOKANA', 'IOBENGUANE SULFATE I 131', 'IOFLUPANE I-123', 'IONSYS', 'IOPIDINE', 'IOSAT', 'IPRATROPIUM BROMIDE', 'IPRIVASK', 'IQUIX', 'IRBESARTAN', 'IRESSA', 'IRINOTECAN HYDROCHLORIDE', 'IRON DEXTRAN', 'ISENTRESS', 'ISENTRESS HD', 'ISMO', 'ISMOTIC', 'ISOFLURANE', 'ISONIAZID', 'ISOPROTERENOL HYDROCHLORIDE', 'ISOPTIN', 'ISOPTO ATROPINE', 'ISOPTO CARPINE', 'ISOPTO CETAMIDE', 'ISORDIL', 'ISOSORBIDE DINITRATE', 'ISOSORBIDE MONONITRATE', 'ISOTRETINOIN', 'ISRADIPINE', 'ISTALOL', 'ISTODAX', 'ISTURISA', 'ISUPREL', 'ITRACONAZOLE', 'IVABRADINE HYDROCHLORIDE', 'IVACAFTOR', 'IVERMECTIN', 'IYUZEH', 'IZBA', 'JADELLE', 'JADENU', 'JAKAFI', 'JANTOVEN', 'JANUVIA', 'JARDIANCE', 'JATENZO', 'JAYPIRCA', 'JELMYTO', 'JENCYCLA', 'JESDUVROQ', 'JOENJA', 'JUBLIA', 'JUNIOR STRENGTH ADVIL', 'JUNIOR STRENGTH IBUPROFEN', 'JUNIOR STRENGTH MOTRIN', 'JUXTAPID', 'JYLAMVO', 'JYNARQUE', 'K-TAB', 'KADIAN', 'KALBITOR', 'KALYDECO', 'KANAMYCIN', 'KANAMYCIN SULFATE', 'KANTREX', 'KAON CL', 'KAPVAY', 'KARBINAL ER', 'KATERZIA', 'KEFLEX', 'KEFLIN', 'KEFUROX', 'KEFZOL', 'KEMADRIN', 'KEMSTRO', 'KENACORT', 'KENALOG', 'KENALOG IN ORABASE', 'KENALOG-10', 'KENALOG-40', 'KENALOG-80', 'KENGREAL', 'KEPPRA', 'KEPPRA XR', 'KERENDIA', 'KERLONE', 'KERYDIN', 'KETALAR', 'KETAMINE HCL', 'KETAMINE HYDROCHLORIDE', 'KETEK', 'KETOCONAZOLE', 'KETOPROFEN', 'KETOROLAC TROMETHAMINE', 'KETOTIFEN FUMARATE', 'KETOZOLE', 'KEVEYIS', 'KHAPZORY', 'KHEDEZLA', 'KIMYRSA', 'KINEVAC', 'KINLYTIC', 'KISQALI', 'KITABIS PAK', 'KLARON', 'KLISYRI', 'KLONOPIN', 'KLOR-CON', 'KLOR-CON M10', 'KLOR-CON M20', 'KLOTRIX', 'KLOXXADO', 'KONAKION', 'KORLYM', 'KORSUVA', 'KOSELUGO', 'KRAZATI', 'KRINTAFEL ...

# %%
print(good_keys[3000:])
# Out:
# ['SEROMYCIN', 'SEROPHENE', 'SEROQUEL', 'SEROQUEL XR', 'SERPANRAY', 'SERTRALINE HYDROCHLORIDE', 'SERZONE', 'SESQUIENT', 'SEVELAMER CARBONATE', 'SEVELAMER HYDROCHLORIDE', 'SEVOFLURANE', 'SEYSARA', 'SEZABY', 'SIGNIFOR', 'SIKLOS', 'SILDENAFIL CITRATE', 'SILENOR', 'SILODOSIN', 'SILPHEN', 'SILVADENE', 'SIMVASTATIN', 'SINCALIDE', 'SINEQUAN', 'SINGULAIR', 'SINUVA', 'SIROLIMUS', 'SIRTURO', 'SITAGLIPTIN PHOSPHATE', 'SITAGLIPTIN PHOSPHATE; METFORMIN HYDROCHLORIDE', 'SITAGLIPTIN; METFORMIN HYDROCHLORIDE', 'SITAVIG', 'SKELID', 'SKLICE', 'SKYCLARYS', 'SKYLA', 'SLO-BID', 'SLOW-K', 'SLYND', 'SOAANZ', 'SODIUM ACETATE', 'SODIUM AMINOSALICYLATE', 'SODIUM BICARBONATE', 'SODIUM FERRIC GLUCONATE COMPLEX IN SUCROSE', 'SODIUM NITRITE', 'SODIUM NITROPRUSSIDE', 'SODIUM OXYBATE', 'SODIUM PHENYLBUTYRATE', 'SODIUM SULFACETAMIDE', 'SODIUM SULFATE; POTASSIUM SULFATE; MAGNESIUM SULFATE', 'SODIUM TETRADECYL SULFATE', 'SODIUM THIOSULFATE', 'SOFOSBUVIR', 'SOGROYA', 'SOHONOS', 'SOJOURN', 'SOLARAZE', 'SOLIFENACIN SUCCINATE', 'SOLODYN', 'SOLOSEC', 'SOLTAMOX', 'SOLU-CORTEF', 'SOMATULINE DEPOT', 'SOMOPHYLLIN', 'SONATA', 'SOOLANTRA', 'SORAFENIB TOSYLATE', 'SORIATANE', 'SORILUX', 'SORINE', 'SOTALOL HYDROCHLORIDE', 'SOTYKTU', 'SOTYLIZE', 'SOVALDI', 'SOVUNA', 'SOY-DOME', 'SPARINE', 'SPECTAZOLE', 'SPECTRACEF', 'SPECTROBID', 'SPIRIVA', 'SPIRIVA RESPIMAT', 'SPIRONOLACTONE', 'SPRAVATO', 'SPRITAM', 'SPRIX', 'SPRYCEL', 'SSD', 'STADOL', 'STARLIX', 'STATICIN', 'STATOBEX', 'STAVUDINE', 'STAVUDINE; LAMIVUDINE', 'STAVUDINE; LAMIVUDINE W/NEVIRAPINE', 'STAVUDINE; LAMIVUDINE; EFAVIRENZ', 'STAVUDINE; LAMIVUDINE; NEVIRAPINE', 'STAVZOR', 'STAXYN', 'STEGLATRO', 'STELAZINE', 'STENDRA', 'STIMATE', 'STIVARGA', 'STRATTERA', 'STREPTOMYCIN SULFATE', 'STRIANT', 'STRIFON FORTE DSC', 'STRIVERDI RESPIMAT', 'STROMECTOL', 'STRONTIUM CHLORIDE SR-89', 'SUBLOCADE', 'SUBSYS', 'SUBUTEX', 'SUCCINYLCHOLINE CHLORIDE', 'SUCOSTRIN', 'SUCRALFATE', 'SUDAFED 12 HOUR', 'SUDAFED 24 HOUR', 'SUFENTANIL CITRATE', 'SULAR', 'SULFACETAMIDE SODIUM', 'SULFADIAZINE', 'SULFADIAZINE SODIUM', 'SULFAMETHOXAZOLE', 'SULFANILAMIDE', 'SULFASALAZINE', 'SULFINPYRAZONE', 'SULFISOXAZOLE', 'SULFISOXAZOLE DIOLAMINE', 'SULINDAC', 'SUMATRIPTAN', 'SUMATRIPTAN SUCCINATE', 'SUMATRIPTAN; NAPROXEN SODIUM', 'SUMAVEL DOSEPRO', 'SUNITINIB MALATE', 'SUNLENCA', 'SUNOSI', 'SUPPRELIN', 'SUPPRELIN LA', 'SUPRANE', 'SUPRAX', 'SUPRENZA', 'SURMONTIL', 'SUSTIVA', 'SUSTOL', 'SUTENT', 'SYMADINE', 'SYMJEPI', 'SYMLIN', 'SYMMETREL', 'SYMPAZAN', 'SYMPROIC', 'SYNACORT', 'SYNALAR', 'SYNAREL', 'SYNDROS', 'SYNRIBO', 'SYNTHROID', 'SYNTOCINON', 'SYPRINE', 'T-STAT', 'TABRECTA', 'TACROLIMUS', 'TADALAFIL', 'TADLIQ', 'TAFINLAR', 'TAFLUPROST', 'TAGAMET', 'TAGAMET HB', 'TAGAMET HB 200', 'TAGRISSO', 'TALWIN', 'TALZENNA', 'TAMBOCOR', 'TAMIFLU', 'TAMOXIFEN CITRATE', 'TAMSULOSIN HYDROCHLORIDE', 'TANZEUM', 'TAPAZOLE', 'TAPENTADOL', 'TAPENTADOL HYDROCHLORIDE', 'TARACTAN', 'TARCEVA', 'TARGRETIN', 'TARPEYO', 'TASCENSO ODT', 'TASIGNA', 'TASIMELTEON', 'TASMAR', 'TAUVID', 'TAVABOROLE', 'TAVALISSE', 'TAVIST', 'TAVIST-1', 'TAVNEOS', 'TAXOL', 'TAXOTERE', 'TAZAROTENE', 'TAZICEF', 'TAZIDIME', 'TAZORAC', 'TAZTIA XT', 'TAZVERIK', 'TECFIDERA', 'TEGRETOL', 'TEGRETOL-XR', 'TEGSEDI', 'TEKTURNA', 'TELMISARTAN', 'TELMISARTAN; HYDROCHLOROTHIAZIDE', 'TEMAZEPAM', 'TEMBEXA', 'TEMODAR', 'TEMOVATE', 'TEMOVATE E', 'TEMOZOLOMIDE', 'TEMSIROLIMUS', 'TENEX', 'TENOFOVIR ALAFENAMIDE', 'TENOFOVIR ALAFENAMIDE FUMARATE', 'TENOFOVIR DISOPROXIL FUMARATE', 'TENORMIN', 'TENSILON', 'TENUATE', 'TENUATE DOSPAN', 'TEPADINA', 'TEPANIL', 'TERAZOL 3', 'TERAZOL 7', 'TERAZOSIN HYDROCHLORIDE', 'TERBINAFINE HYDROCHLORIDE', 'TERBUTALINE SULFATE', 'TERCONAZOLE', 'TERIFLUNOMIDE', 'TERIL', 'TERLIVAZ', 'TESLASCAN', 'TESSALON', 'TESTIM', 'TESTODERM', 'TESTODERM TTS', 'TESTOPEL', 'TESTOSTERONE', 'TESTOSTERONE CYPIONATE', 'TESTOSTERONE ENANTHATE', 'TESTOSTERONE PROPIONATE', 'TESTOSTERONE UNDECANOATE', 'TESTRED', 'TETRABENAZINE', 'TETRACAINE HYDROCHLORIDE', 'TETRACYCLINE HYDROCHLORIDE', 'TEVETEN', 'TEXACORT', 'THALIDOMIDE', 'THALITONE', ...

# %%
import json

def count_unique_contents(file_path):
    unique_contents = set()

    with open(file_path, 'r') as file:
        for line in file:
            data = json.loads(line)
            for message in data['messages']:
                content = message['content']
                unique_contents.add(content)

    return len(unique_contents)
# Out:
# Running cells with 'dmpred' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n dmpred ipykernel --update-deps --force-reinstall'
